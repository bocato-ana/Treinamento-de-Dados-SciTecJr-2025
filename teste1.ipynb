# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
print('Biblioteca importada com sucesso!')
# Out:
# Biblioteca importada com sucesso!

# %%
df = pd.read_csv('Student Mental Health.csv')
print(f'Dataset carregado com sucesso! Shape:{df.shape}')
df
# Out:
# Dataset carregado com sucesso! Shape:(101, 11)
#                Timestamp Choose your gender   Age What is your course?  \
# 0         8/7/2020 12:02             Female  18.0          Engineering
# 1         8/7/2020 12:04               Male  21.0    Islamic education
# 2         8/7/2020 12:05               Male  19.0                  BIT
# 3         8/7/2020 12:06             Female  22.0                 Laws
# 4         8/7/2020 12:13               Male  23.0         Mathemathics
# ..                   ...                ...   ...                  ...
# 96   13/07/2020 19:56:49             Female  21.0                  BCS
# 97   13/07/2020 21:21:42               Male  18.0          Engineering
# 98   13/07/2020 21:22:56             Female  19.0             Nursing
# 99   13/07/2020 21:23:57             Female  23.0     Pendidikan Islam
# 100  18/07/2020 20:16:21               Male  20.0   Biomedical science
#
#     Your current year of Study What is your CGPA? Marital status  \
# ...

# %%
df = df.drop(columns=['What is your CGPA?', 'Your current year of Study', 'Timestamp'])
df
# Out:
#     Choose your gender   Age What is your course? Marital status  \
# 0               Female  18.0          Engineering             No
# 1                 Male  21.0    Islamic education             No
# 2                 Male  19.0                  BIT             No
# 3               Female  22.0                 Laws            Yes
# 4                 Male  23.0         Mathemathics             No
# ..                 ...   ...                  ...            ...
# 96              Female  21.0                  BCS             No
# 97                Male  18.0          Engineering             No
# 98              Female  19.0             Nursing             Yes
# 99              Female  23.0     Pendidikan Islam             No
# 100               Male  20.0   Biomedical science             No
#
#     Do you have Depression? Do you have Anxiety? Do you have Panic attack?  \
# 0                       Yes                   No                       Yes
# ...

# %%
print(df.columns.tolist())
# Out:
# ['Choose your gender', 'Age', 'What is your course?', 'Marital status', 'Do you have Depression?', 'Do you have Anxiety?', 'Do you have Panic attack?', 'Did you seek any specialist for a treatment?']

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 8 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Choose your gender                            101 non-null    object
#  1   Age                                           100 non-null    float64
#  2   What is your course?                          101 non-null    object
#  3   Marital status                                101 non-null    object
#  4   Do you have Depression?                       101 non-null    object
#  5   Do you have Anxiety?                          101 non-null    object
#  6   Do you have Panic attack?                     101 non-null    object
#  7   Did you seek any specialist for a treatment?  101 non-null    object
# dtypes: float64(1), object(7)
# memory usage: 37.2 KB

# %%
df['Choose your gender']=df['Choose your gender'].map({'Male': 1, 'Female': 0}).astype('bool')
df['Marital status']=df['Marital status'].map({'No': 0, 'Yes': 1}).astype('bool')
df['Do you have Depression?']=df['Do you have Depression?'].map({'No': 0, 'Yes': 1}).astype('Int8')
df['Do you have Anxiety?']=df['Do you have Anxiety?'].map({'No': 0, 'Yes': 1}).astype('Int8')
df['Do you have Panic attack?']=df['Do you have Panic attack?'].map({'No': 0, 'Yes': 1}).astype('Int8')
df['Did you seek any specialist for a treatment?']=df['Did you seek any specialist for a treatment?'].map({'No': 0, 'Yes': 1}).astype('Int8')
df
# Out:
#      Choose your gender   Age What is your course?  Marital status  \
# 0                 False  18.0          Engineering           False
# 1                  True  21.0    Islamic education           False
# 2                  True  19.0                  BIT           False
# 3                 False  22.0                 Laws            True
# 4                  True  23.0         Mathemathics           False
# ..                  ...   ...                  ...             ...
# 96                False  21.0                  BCS           False
# 97                 True  18.0          Engineering           False
# 98                False  19.0             Nursing             True
# 99                False  23.0     Pendidikan Islam           False
# 100                True  20.0   Biomedical science           False
#
#      Do you have Depression?  Do you have Anxiety?  Do you have Panic attack?  \
# 0                          1                     0                          1
# ...

# %%
df['Age']=df['Age'].astype('Int8')
df
# Out:
#      Choose your gender  Age What is your course?  Marital status  \
# 0                 False   18          Engineering           False
# 1                  True   21    Islamic education           False
# 2                  True   19                  BIT           False
# 3                 False   22                 Laws            True
# 4                  True   23         Mathemathics           False
# ..                  ...  ...                  ...             ...
# 96                False   21                  BCS           False
# 97                 True   18          Engineering           False
# 98                False   19             Nursing             True
# 99                False   23     Pendidikan Islam           False
# 100                True   20   Biomedical science           False
#
#      Do you have Depression?  Do you have Anxiety?  Do you have Panic attack?  \
# 0                          1                     0                          1
# ...

# %%
list(df['What is your course?'].unique())

df['What is your course?'] = df['What is your course?'].map({   'Engineering': 'Engineering',
                                                                'Engine': 'Engineering',
                                                                'engin': 'Engineering',
                                                                'KOE': 'Engineering',
                                                                'koe': 'Engineering',
                                                                'Koe': 'Engineering',

                                                                # Direito
                                                                'Law': 'Law',
                                                                'Laws': 'Law',

                                                                # Psicologia
                                                                'Psychology': 'Psychology',
                                                                'psychology': 'Psychology',

                                                                # Educação Islâmica
                                                                'Islamic education': 'Islamic Education',
                                                                'Islamic Education': 'Islamic Education',
                                                                'Pendidikan islam': 'Islamic Education',
                                                                'Pendidikan Islam ': 'Islamic Education',
                                                                'Pendidikan Islam': 'Islamic Education',
                                                                'Usuluddin ': 'Islamic Education',
                                                                'Fiqh fatwa ': 'Islamic Education',
                                                                'Fiqh': 'Islamic Education',

                                                                # TI e Computação
                                                                'BIT': 'Information Technology',
                                                                'BCS': 'Information Technology',
                                                                'IT': 'Information Technology',
                                                                'CTS': 'Information Technology',

                                                                # Ciências Humanas / Humanidades
                                                                'Irkhs': 'Human Sciences',
                                                                'KIRKHS': 'Human Sciences',
                                                                'Kirkhs': 'Human Sciences',
                                                                'Human Sciences ': 'Human Sciences',
                                                                'ALA': 'Human Sciences',
                                                                'TAASL': 'Human Sciences',
                                                                'BENL': 'Human Sciences',
                                                                'Benl': 'Human Sciences',
                                                                'Malcom': 'Human Sciences',
                                                                'DIPLOMA TESL': 'Human Sciences',

                                                                # Administração e Negócios
                                                                'Business Administration': 'Business & Economics',
                                                                'Banking Studies': 'Business & Economics',
                                                                'Accounting ': 'Business & Economics',
                                                                'KENMS': 'Business & Economics',
                                                                'Econs': 'Business & Economics',
                                                                'MHSC': 'Business & Economics',

                                                                # Ciências da Saúde
                                                                'Diploma Nursing': 'Health Sciences',
                                                                'Nursing ': 'Health Sciences',
                                                                'Radiography': 'Health Sciences',
                                                                'Biomedical science': 'Health Sciences',
                                                                'Biotechnology': 'Health Sciences',
                                                                'Kop': 'Health Sciences',

                                                                # Recursos Humanos
                                                                'Human Resources': 'Human Resources',

                                                                # Comunicação
                                                                'Communication ': 'Communication',

                                                                # Ciências Marinhas
                                                                'Marine science': 'Marine Science',

                                                                # Matemática
                                                                'Mathemathics': 'Mathematics',}).astype('category')

df
# Out:
#      Choose your gender  Age    What is your course?  Marital status  \
# 0                 False   18             Engineering           False
# 1                  True   21       Islamic Education           False
# 2                  True   19  Information Technology           False
# 3                 False   22                     Law            True
# 4                  True   23             Mathematics           False
# ..                  ...  ...                     ...             ...
# 96                False   21  Information Technology           False
# 97                 True   18             Engineering           False
# 98                False   19         Health Sciences            True
# 99                False   23       Islamic Education           False
# 100                True   20         Health Sciences           False
#
#      Do you have Depression?  Do you have Anxiety?  Do you have Panic attack?  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 8 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Choose your gender                            101 non-null    bool
#  1   Age                                           100 non-null    Int8
#  2   What is your course?                          100 non-null    category
#  3   Marital status                                101 non-null    bool
#  4   Do you have Depression?                       101 non-null    Int8
#  5   Do you have Anxiety?                          101 non-null    Int8
#  6   Do you have Panic attack?                     101 non-null    Int8
#  7   Did you seek any specialist for a treatment?  101 non-null    Int8
# dtypes: Int8(5), bool(2), category(1)
# memory usage: 1.8 KB

# %%
df.memory_usage(deep=True)
# Out:
# Index                                            132
# Choose your gender                               101
# Age                                              202
# What is your course?                            1154
# Marital status                                   101
# Do you have Depression?                          202
# Do you have Anxiety?                             202
# Do you have Panic attack?                        202
# Did you seek any specialist for a treatment?     202
# dtype: int64

# %%
df.to_parquet('Student Mental health.parquet', index=False)

# %%
df2 = pd.read_parquet('Student Mental health.parquet')
df2
# Out:
#      Choose your gender  Age    What is your course?  Marital status  \
# 0                 False   18             Engineering           False
# 1                  True   21       Islamic Education           False
# 2                  True   19  Information Technology           False
# 3                 False   22                     Law            True
# 4                  True   23             Mathematics           False
# ..                  ...  ...                     ...             ...
# 96                False   21  Information Technology           False
# 97                 True   18             Engineering           False
# 98                False   19         Health Sciences            True
# 99                False   23       Islamic Education           False
# 100                True   20         Health Sciences           False
#
#      Do you have Depression?  Do you have Anxiety?  Do you have Panic attack?  \
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 8 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Choose your gender                            101 non-null    bool
#  1   Age                                           100 non-null    Int8
#  2   What is your course?                          100 non-null    category
#  3   Marital status                                101 non-null    bool
#  4   Do you have Depression?                       101 non-null    Int8
#  5   Do you have Anxiety?                          101 non-null    Int8
#  6   Do you have Panic attack?                     101 non-null    Int8
#  7   Did you seek any specialist for a treatment?  101 non-null    Int8
# dtypes: Int8(5), bool(2), category(1)
# memory usage: 1.8 KB

# %%
df.describe().T
# Out:
#                                               count      mean       std   min  \
# Age                                           100.0     20.53   2.49628  18.0
# Do you have Depression?                       101.0  0.346535  0.478239   0.0
# Do you have Anxiety?                          101.0  0.336634  0.474915   0.0
# Do you have Panic attack?                     101.0  0.326733  0.471358   0.0
# Did you seek any specialist for a treatment?  101.0  0.059406  0.237562   0.0
#
#                                                25%   50%   75%   max
# Age                                           18.0  19.0  23.0  24.0
# Do you have Depression?                        0.0   0.0   1.0   1.0
# Do you have Anxiety?                           0.0   0.0   1.0   1.0
# Do you have Panic attack?                      0.0   0.0   1.0   1.0
# Did you seek any specialist for a treatment?   0.0   0.0   0.0   1.0

# %%
df.to_csv('Student Mental health.csv', index=False)

# %% [markdown]
# Parte 2 - Criando gráficos!

# %%
#criando graficos lado a lado
fig, axes = plt.subplots(1, 3, figsize=(24, 6))

#Histograma 'Age'"Student Mental health.csv"
sns.histplot(df['Age'], bins=7, kde=True, ax=axes[0], color='salmon')
axes[0].set_title('Distribuição da idade dos Entrevistados')
axes[0].set_xlabel('Idade')
axes[0].set_ylabel('Quantidade')

#Grafico de pizza idade
genero_counts = df['Choose your gender'].value_counts()
genero_counts.index = genero_counts.index.map({True:'Male' , False:'Female'})

axes[1].pie(
    genero_counts,
    labels=genero_counts.index,
    autopct='%1.1f%%',
    startangle=90,
    colors=['pink', 'skyblue', 'lightgray']
)
axes[1].set_title('Distribuição por genêro')
axes[1].axis('equal')

#Gráfico de Pizza matrimonio
matrimonio_counts = df['Marital status'].value_counts()
matrimonio_counts.index = matrimonio_counts.index.map({False:'No', True:'Yes'})

axes[2].pie(
    matrimonio_counts,
    labels=matrimonio_counts.index,
    autopct='%1.1f%%',
    startangle=90,
    colors=['lightgreen', 'lightyellow']
)
axes[2].set_title('Situação Matrimonial')
axes[2].axis('equal')


#sem sobreposição
plt.tight_layout()
plt.show()

# %%
colunas = ['Do you have Depression?', 'Do you have Anxiety?', 'Do you have Panic attack?']
contagens = df[colunas].sum()

plt.figure(figsize=(8,6))
plt.bar(contagens.index, contagens.values, color='skyblue')  # ← CORRIGIDO AQUI

plt.title('Doenças Mentais')
plt.xlabel('Condição')
plt.ylabel('Quantidade de Pessoas')

plt.tight_layout()
plt.show()

# %%
doenças = ['Do you have Depression?', 'Do you have Anxiety?', 'Do you have Panic attack?']

df_melt = df.melt(
    id_vars=['Age', 'Did you seek any specialist for a treatment?'],
    value_vars=doenças,
    var_name='Doença',
    value_name='Tem'
)

# Filtra apenas quem respondeu "Sim" para cada doença
df_melt = df_melt[df_melt['Tem'] == True]
df_melt['Tratamento (%)'] = df_melt['Did you seek any specialist for a treatment?'] * 100

sns.scatterplot(data=df_melt, x='Age', y='Did you seek any specialist for a treatment?', hue='Doença', alpha=0.7, palette='Set2')
plt.title('Relação entre Idade e Tempo de Tela por Gênero')
plt.xlabel('Idade')
plt.ylabel('Procuraram Ajuda')
plt.yticks([0, 25, 50, 75, 100])  # define os intervalos visíveis no Y
plt.legend(title='Doenças')
plt.show()

plt.tight_layout()
plt.show()

# %%
colunas = ['Do you have Depression?', 'Do you have Anxiety?', 'Do you have Panic attack?']

contagens = {}

for coluna in colunas:
    cont = 0
    for i in range(len(df)):
        if df[coluna].iloc[i] == 1 and df['Did you seek any specialist for a treatment?'].iloc[i] == 1:
            cont += 1
    contagens[coluna] = cont

print(contagens)

plt.figure(figsize=(8,6))
plt.bar(contagens.keys(), contagens.values(), color='orchid')
plt.title('Pessoas que Procuraram Ajuda por Tipo de Doença Mental')
plt.xlabel('Condição')
plt.ylabel('Quantidade de Pessoas')
plt.xticks(rotation=20)
plt.tight_layout()
plt.show()
# Out:
# {'Do you have Depression?': 6, 'Do you have Anxiety?': 3, 'Do you have Panic attack?': 4}

# %%
# 1. Verifica se a pessoa tem pelo menos uma doença mental
df['Tem_alguma_doenca'] = (
    (df['Do you have Depression?'] == 1) |
    (df['Do you have Anxiety?'] == 1) |
    (df['Do you have Panic attack?'] == 1)
)

# 2. Cria categorias combinando estado civil e presença de doença
def classificar_pessoa(row):
    if row['Marital status'] == 1 and row['Tem_alguma_doenca']:
        return 'Casado e com Doença Mental'
    elif row['Marital status'] == 1:
        return 'Casado e Saudável'
    elif row['Marital status'] == 0 and row['Tem_alguma_doenca']:
        return 'Não Casado e com Doença'
    else:
        return 'Não Casado e Saudável'

df['Categoria_Mental_Marital'] = df.apply(classificar_pessoa, axis=1)

# 3. Conta as categorias
contagem = df['Categoria_Mental_Marital'].value_counts()

# 4. Cria o gráfico de pizza
cores = ['green', 'lightgreen', 'red', 'lightcoral']
plt.figure(figsize=(6,6))
plt.pie(
    contagem,
    labels=contagem.index,
    autopct='%1.1f%%',
    startangle=90,
    colors=cores
)
plt.title('Relação entre Estado Civil e Doença Mental')
plt.axis('equal')
plt.tight_layout()
plt.show()
